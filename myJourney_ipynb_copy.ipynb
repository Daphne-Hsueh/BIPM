# %% [markdown]
# <a href="https://colab.research.google.com/github/Daphne-Hsueh/BIPM/blob/main/%E3%80%8CmyJourney_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Generate inmteractive map and save as standalone html page.
#
# (Try different tile servers)

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from folium) (2.3.4)
# Requirement already satisfied: requests in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hdaphne/PycharmProjects/PythonProject/DataCamp/.venv/lib/python3.13/site-packages (from requests->folium) (2025.10.5)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import folium
from pyproj import Geod

geod = Geod(ellps="WGS84")

# Define stops
stops = [
    {"city": "Chiayi, Taiwan", "lat": 23.5, "lon": 120.27, "popup": "Born and raised 🦃"},
    {"city": "Taipei, Taiwan", "lat": 25.3573, "lon": 121.6672, "popup": "Bachelor - Business Administration 🎓"},
    {"city": "Masstricht, Netherlands", "lat": 50.7831, "lon": 5.9712, "popup": "Exchange semester ✈️"},
    {"city": "Berlin, Germany", "lat": 52.5200, "lon": 13.4050, "popup": "Master - BIPM HWR Berlin 🏫"}
]

# Create map
m = folium.Map(
    location=[40, 0],
    zoom_start=2.3,
    tiles="https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
    attr="© OpenStreetMap contributors © CARTO"
)

# Add markers
for stop in stops:
    folium.Marker(
        [stop["lat"], stop["lon"]],
        popup=stop["popup"],
        tooltip=stop["city"],
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)

# Function to compute many intermediate great-circle points
def great_circle_points(lat1, lon1, lat2, lon2, npts=100):
    points = geod.npts(lon1, lat1, lon2, lat2, npts)
    coords = [(lat1, lon1)] + [(lat, lon) for lon, lat in points] + [(lat2, lon2)]
    return coords

# Draw arcs between consecutive stops
for i in range(len(stops) - 1):
    start, end = stops[i], stops[i + 1]
    arc = great_circle_points(start["lat"], start["lon"], end["lat"], end["lon"], npts=60)
    folium.PolyLine(
        arc,
        color="darkblue",
        weight=3,
        opacity=0.7
    ).add_to(m)

# Save and open
m.save("journey.html")

# %% [markdown]
# Saving this on google drive !

# %%
# from google.colab import drive
# drive.mount('/content/drive')

#This is my path:
save_path = 'journey.html'

# %%
m.save(save_path)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2c35270e2ffe700a7015918a9f1e981 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2c35270e2ffe700a7015918a9f1e981&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2c35270e2ffe700a7015918a9f1e981 = L.map(
#                 &quot;map_a2c35270e2ffe700a7015918a9f1e981&quot;,
#                 {
#                     center: [40.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2.3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7eede9ac313bd454cbaff43dfed23e89 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 OpenStreetMap contributors \u00a9 CARTO&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7eede9ac313bd454cbaff43dfed23e89.addTo(map_a2c35270e2ffe700a7015918a9f1e981);
#
#
#             var marker_f606df315014d9e6492219d5f1ab5ddf = L.marker(
#                 [23.5, 120.27],
#                 {
# }
#             ).addTo(map_a2c35270e2ffe700a7015918a9f1e981);
#
#
#             var icon_5dcd8f18dc0e0dca9c1c2e1c9cb1284a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3f7d092dbba09784102c6a85223e027 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c00f99c13ba6cd844dc76875d044a5bf = $(`&lt;div id=&quot;html_c00f99c13ba6cd844dc76875d044a5bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Born and raised 🦃&lt;/div&gt;`)[0];
#                 popup_a3f7d092dbba09784102c6a85223e027.setContent(html_c00f99c13ba6cd844dc76875d044a5bf);
#
#
#
#         marker_f606df315014d9e6492219d5f1ab5ddf.bindPopup(popup_a3f7d092dbba09784102c6a85223e027)
#         ;
#
#
#
#
#             marker_f606df315014d9e6492219d5f1ab5ddf.bindTooltip(
#                 `&lt;div&gt;
#                      Chiayi, Taiwan
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f606df315014d9e6492219d5f1ab5ddf.setIcon(icon_5dcd8f18dc0e0dca9c1c2e1c9cb1284a);
#
#
#             var marker_cc154add93b020b25a75beb810f474fb = L.marker(
#                 [25.3573, 121.6672],
#                 {
# }
#             ).addTo(map_a2c35270e2ffe700a7015918a9f1e981);
#
#
#             var icon_800566715c341ec81d2436a93994505b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e6024fcfeb2dccd81f8e6e5107311447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c18b0a56e3dbc768b67dd74cc3dfc33a = $(`&lt;div id=&quot;html_c18b0a56e3dbc768b67dd74cc3dfc33a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bachelor - Business Administration 🎓&lt;/div&gt;`)[0];
#                 popup_e6024fcfeb2dccd81f8e6e5107311447.setContent(html_c18b0a56e3dbc768b67dd74cc3dfc33a);
#
#
#
#         marker_cc154add93b020b25a75beb810f474fb.bindPopup(popup_e6024fcfeb2dccd81f8e6e5107311447)
#         ;
#
#
#
#
#             marker_cc154add93b020b25a75beb810f474fb.bindTooltip(
#                 `&lt;div&gt;
#                      Taipei, Taiwan
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_cc154add93b020b25a75beb810f474fb.setIcon(icon_800566715c341ec81d2436a93994505b);
#
#
#             var marker_856fdf7b62c5b36d8ac33da2c3fedede = L.marker(
#                 [50.7831, 5.9712],
#                 {
# }
#             ).addTo(map_a2c35270e2ffe700a7015918a9f1e981);
#
#
#             var icon_ae0265a7f65d869305f1441a14577ba2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_da4eb7d19d2e5bb9770d6f94e29181f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf8cf0f48b3830efb94d32599062bb66 = $(`&lt;div id=&quot;html_cf8cf0f48b3830efb94d32599062bb66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Exchange semester ✈️&lt;/div&gt;`)[0];
